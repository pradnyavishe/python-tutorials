# %% [markdown]
# syntax:
# my_dict = {'key1':'value1', 'key2':'value2', ...}

# %% [markdown]
# **# Methods to create dictionary**

# %% [markdown]
# **# method-1: create dictionary using curly braces**

# %%
cohort = {'Course':'Python',
          'Instructor':'Rishabh Mishra',
          'Level':'Beginner'}
print(cohort)
print(type(cohort))
# Out:
# {'Course': 'Python', 'Instructor': 'Rishabh Mishra', 'Level': 'Beginner'}
# <class 'dict'>

# %% [markdown]
# **# method-2: using dict() constructor**

# %%
person = dict(name='Madhav', age=28, grade='A')
print(person)
print(type(person))
# Out:
# {'name': 'Madhav', 'age': 28, 'grade': 'A'}
# <class 'dict'>

# %% [markdown]
# **# method-3: using list of tuples**

# %%
person2 = dict([('name', 'Madhav'), ('age', 28), ('city', 'Mathura')])
print(person2)
print(type(person2))
# Out:
# {'name': 'Madhav', 'age': 28, 'city': 'Mathura'}
# <class 'dict'>

# %% [markdown]
# **# Access dictionary values**

# %%
student = {
    1 : 'Class-X',
    'name' : 'Madhavi',
    'grade' : 'A',
    'city' : 'Mathura'
}

print(student)
print(type(student))

print(student['city'])
print(student[1])
print(student['grade'])
# Out:
# {1: 'Class-X', 'name': 'Madhavi', 'grade': 'A', 'city': 'Mathura'}
# <class 'dict'>
# Mathura
# Class-X
# A

# %% [markdown]
# **# Dictionary Methods**

# %%
student = {
    1 : 'Class-X',
    'name' : 'Madhavi',
    'grade' : 'A',
    'city' : 'Mathura'
}

# keys
print(student.keys())

# values
print(student.values())

# items
print(student.items())

# get
print(student['name'])
print(student.get('name'))
print(student.get('email'))
print(student.get('email', 'nahi hai'))

# add/modify items in dictionary
student = {
    'name' : 'Madhavi',
    'grade' : 'A',
    'city' : 'Mathura'
}

# add item - assign operator
student['email'] = 'machavi@example.com'
print(student)

# modify/replace item - assign operator
student['grade'] = 'A+'
print(student)

# remove items
# del to remove item
del student['grade']
print(student)

# pop method
var1 = student.pop('email')
print(var1)
print(student)
# Out:
# dict_keys([1, 'name', 'grade', 'city'])
# dict_values(['Class-X', 'Madhavi', 'A', 'Mathura'])
# dict_items([(1, 'Class-X'), ('name', 'Madhavi'), ('grade', 'A'), ('city', 'Mathura')])
# Madhavi
# Madhavi
# None
# nahi hai
# {'name': 'Madhavi', 'grade': 'A', 'city': 'Mathura', 'email': 'machavi@example.com'}
# {'name': 'Madhavi', 'grade': 'A+', 'city': 'Mathura', 'email': 'machavi@example.com'}
# {'name': 'Madhavi', 'city': 'Mathura', 'email': 'machavi@example.com'}
# machavi@example.com
# {'name': 'Madhavi', 'city': 'Mathura'}

# %% [markdown]
# **# Dictionary Iteration**

# %%
student = {
    'name' : 'Madhavi',
    'grade' : 'A',
    'city' : 'Mathura'
}

# loop through keys
for keys in student:
    print(keys)

# loop through values
for value in student:
    print(student[value]) 

# using .value() method
for value in student.values():
    print(value)    

# loop through both key-value pair
for key, value in student.items():
    print(key, value)
# Out:
# name
# grade
# city
# Madhavi
# A
# Mathura
# Madhavi
# A
# Mathura
# name Madhavi
# grade A
# city Mathura

# %% [markdown]
# **# Nested Dictionary**

# %%
main_student = {
    'student1' : {'name' : 'Madhavi', 'age' : 28},
    'student2' : {'name' : 'Keshavi', 'age' : 30, 'grade' : 'A'}
}

print(main_student)

# access value
print(main_student['student1'])

print(main_student['student1'] ['name'])
print(main_student['student2'] ['name'])
print(main_student['student2'] ['grade'])
# Out:
# {'student1': {'name': 'Madhavi', 'age': 28}, 'student2': {'name': 'Keshavi', 'age': 30, 'grade': 'A'}}
# {'name': 'Madhavi', 'age': 28}
# Madhavi
# Keshavi
# A

# %% [markdown]
# **# Dictionary Comprehension**

# %% [markdown]
# **syntax**
#
# new_dict = {key_exp : value_exp for item in iterable if condition}

# %%
my_dict = {x : x+x for x in range(1, 6)}

print(my_dict)
# Out:
# {1: 2, 2: 4, 3: 6, 4: 8, 5: 10}
