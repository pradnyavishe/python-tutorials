# %% [markdown]
# **#Input Function in Python**

# %%
p = input()
print(p)

name = input("Enter your name: ")
print("Hello,", name)
# Out:
# abs

# %%
name = input("Enter your name: ")
sub1 = input("Enter marks of Maths out of 100: ")
sub2 = input("Enter marks of Science out of 100: ")
sub3 = input(" Enter marks of Histpry out of 100: ")
percentage = (((int(sub1) + int(sub2) + int(sub3))/300))*100
print(f" {name} got {percentage} %")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       3 sub2 = input("Enter marks of Science out of 100: ")
#       4 sub3 = input(" Enter marks of Histpry out of 100: ")
# ----> 5 percentage = (((int(sub1) + int(sub2) + int(sub3))/300))*100
#       6 print(f" {name} got {percentage} %")
#
# ValueError: invalid literal for int() with base 10: ''
