# %%
# Q2: For a business create 3 variables to store- name, age, and city. Then print a sentence that uses these variables.
name = "Pradnya"
age = 28
city = "Munbai"
print("My name is", name, "from", city, "and i am", age)
# Out:
# My name is Pradnya from Munbai and i am 28

# %%
age = '28'
date = '12/06/25'
print(type(age))
print(type(date))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# #### **practice for data type**
