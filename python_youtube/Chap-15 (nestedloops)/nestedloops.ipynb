# %% [markdown]
# **# Loops in Python - Nested Loop**

# %%
# loop inside another loop

# syntax

# outer_loop:
#     inner_loop:
#         # block of code for inner loop
# # block of code for outer loop  

# print numbers from 1 to 3 for 3 times

for i in range(3):
    # print("Outer loop iteration no, ", i)
    for num in range(1, 4):
        print(num)
    print("---")
# Out:
# Outer loop iteration no,  0
# 1
# 2
# 3
# ---
# Outer loop iteration no,  1
# 1
# 2
# 3
# ---
# Outer loop iteration no,  2
# 1
# 2
# 3
# ---

# %%
# print numbers from 1 to 3 using while-for loop : nested loop

i = 1
while i < 4:
    print("while loop iteration no", i)
    for j in range(1, 4):
        print(j)
    # print("---") 
    i += 1
# Out:
# while loop iteration no 1
# 1
# 2
# 3
# ---
# while loop iteration no 2
# 1
# 2
# 3
# ---
# while loop iteration no 3
# 1
# 2
# 3
# ---

# %%
# print prime numbers between range of 2 to 10 using nested loop:

for num in range(2, 20):
    for i in range(2, num):
        if num % i == 0:
            break
    else:
        print(num)
# Out:
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19
