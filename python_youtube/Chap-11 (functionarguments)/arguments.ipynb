# %% [markdown]
# **# Arguments in Functions: 1.Required Arguments (Single/Mutiple Arguments)**

# %%
def greetings(name):                    # name is parameter
    print("Hello ", name, "!")

greetings("Madhavi")                    # Madhavi is argument
# greetings()                           # required an argument to run code
# Out:
# Hello  Madhavi !

# %%
def intro(course_name, instructor_name):
    print("Welcome to", course_name, "course_by", instructor_name)

intro("Python", "Rishabh")
# Out:
# Welcome to Python course_by Rishabh

# %% [markdown]
# **2. Default Arguments**

# %%
def greetings(name = "world"):         # "World" is a default value
    print("Hello ", name, "!")

greetings()                            # runs without error using default value

greetings("Pradnya")
# Out:
# Hello  world !
# Hello  Pradnya !

# %% [markdown]
# **3. Keyword Arguments (Named Arguments)**

# %%
def divide(a, b):
    return a / b

result1 = divide(100, 20)              # positinal arguments
print(result1)

result2 = divide(b=100, a=20)          # named/keyword arguments
print(result2)
# Out:
# 5.0
# 0.2

# %% [markdown]
# 4. Arbitrary Arguments (Variable-length Arguments *args and **kwargs)

# %%
# Arbitrary Positional Argument (*args)

# Note: stores arguments as tuple

def add2number(a, b):
    return a + b

result = add2number(10, 11)
print(result)

def add3number(a, b, c):
    return a + b + c

result1 = add3number(10, 11, 12)
print(result1)

def add_number(*args):
    print(type(args))
    return sum(args)

output = add_number(1, 2, 5, 8, 4)    # variable no. of arguments
print(output)

def greetings2(*names):
    for name in names:
        print(f"Hello, {name}!")

greetings2("Madhavi", "Pradnya", "Bhumi")
# Out:
# 21
# 33
# <class 'tuple'>
# 20
# Hello, Madhavi!
# Hello, Pradnya!
# Hello, Bhumi!

# %%
# Arbitrary Keywork Argument (**kwargs)

# Note: stores arguments as dictionary

def print_details(**kwargs):
    # print(type(kwargs))                      # dictionary type
    for key, value in kwargs.items():
        print(f"{key} : {value}")

print_details(name = "Madhavi", age = 27, city = "Delhi")     

# print_details(name = "Madhavi", age = 27)
# Out:
# name : Madhavi
# age : 27
# city : Delhi
