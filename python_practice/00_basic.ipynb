# %%
n = 0
# print (n)
while n < 6:
    print(f"Hello", n)
    n +=1
# Out:
# Hello 0
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5

# %%
for i in range(1, 6):
    print(f"Hello", i)
# Out:
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5

# %%
# a = input("Enter what number you want to print")
# b = 1
# # print(f"Hello", a)

# while b < 6:
#     print(f"Hello", a)
#     b+=1


a = int(input("Enter what number you want to print"))
b = 1

while b <=int(a):
    print(f"Hello", b)
    b+=1
# Out:
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5
# Hello 6
# Hello 7
# Hello 8
# Hello 9
